# %% [markdown]
# # Initial Steps

# %% [markdown]
# - `mkdir -p ./DWREApiDoc.docset/Contents/Resources/Documents`
# - copy scriptapi/api to Documents/api and pipeletapi/api to Documents/pipelet (i.e. rename folder to pipelet)
# - Run this script

# %%
from pyquery import PyQuery as pq
import sqlite3
import os.path
import shutil
import markdown
from markdown.extensions.tables import TableExtension
from markdown.extensions.fenced_code import FencedCodeExtension
from markdown.extensions.codehilite import CodeHiliteExtension
from jinja2 import Template
import requests

# %%
PLIST = """<?xml version="1.0" encoding="UTF-8"?>
<!DOCTYPE plist PUBLIC "-//Apple//DTD PLIST 1.0//EN" "http://www.apple.com/DTDs/PropertyList-1.0.dtd">
<plist version="1.0">
<dict>
<key>CFBundleIdentifier</key>
<string>dwre</string>
<key>CFBundleName</key>
<string>DWRE</string>
<key>DocSetPlatformFamily</key>
<string>dwre</string>
<key>isDashDocset</key>
<true/>
</dict>
</plist>"""

# %% [markdown]
# # Init

# %%
if os.path.exists("./DWREApiDoc.docset/Contents/"):
    shutil.rmtree("./DWREApiDoc.docset/Contents/")

if not os.path.exists('./DWREApiDoc.docset/Contents/Resources/Documents/'):
    os.makedirs('./DWREApiDoc.docset/Contents/Resources/Documents/')

shutil.copy('./dwredocs/code.css', './DWREApiDoc.docset/Contents/Resources/Documents/code.css')

with open('./DWREApiDoc.docset/Contents/Info.plist', 'w') as f:
    f.write(PLIST)
    
conn = sqlite3.connect('./DWREApiDoc.docset/Contents/Resources/docSet.dsidx')
c = conn.cursor()
c.execute("CREATE TABLE IF NOT EXISTS searchIndex(id INTEGER PRIMARY KEY, name TEXT, type TEXT, path TEXT);")
c.execute("CREATE UNIQUE INDEX IF NOT EXISTS anchor ON searchIndex (name, type, path);")
conn.commit()

# %% [markdown]
# # Script API

# %%
if os.path.exists("./DWREApiDoc.docset/Contents/Resources/Documents/api"):
    shutil.rmtree("./DWREApiDoc.docset/Contents/Resources/Documents/api")
shutil.copytree("./dwredocs/scriptapi/html/api", "./DWREApiDoc.docset/Contents/Resources/Documents/api")
# Out:
# './DWREApiDoc.docset/Contents/Resources/Documents/api'

# %%
with open("./DWREApiDoc.docset/Contents/Resources/Documents/api/classList.html", "r") as f:
    d = pq(f.read())
    
c = conn.cursor()

for link in d('.classesName a'):
    title = link.attrib["title"]
    name = link.text
    path = link.attrib["href"]
    
    print(name, title, path)
    
    c.execute("INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('%s', 'Class', '%s');" % 
              (name, "api/%s" % path))
    
conn.commit()
def test():
    pass
# Out:
# global Class in TopLevel class_TopLevel_global.html
# AbstractItem Class in dw.order class_dw_order_AbstractItem.html
# AbstractItemCtnr Class in dw.order class_dw_order_AbstractItemCtnr.html
# ABTest Class in dw.campaign class_dw_campaign_ABTest.html
# ABTestMgr Class in dw.campaign class_dw_campaign_ABTestMgr.html
# ABTestSegment Class in dw.campaign class_dw_campaign_ABTestSegment.html
# ActiveData Class in dw.object class_dw_object_ActiveData.html
# AddressBook Class in dw.customer class_dw_customer_AddressBook.html
# AgentUserMgr Class in dw.customer class_dw_customer_AgentUserMgr.html
# AgentUserStatusCodes Class in dw.system class_dw_system_AgentUserStatusCodes.html
# AgentUserStatusCodes Class in dw.customer class_dw_customer_AgentUserStatusCodes.html
# AmountDiscount Class in dw.campaign class_dw_campaign_AmountDiscount.html
# APIException Class in TopLevel class_TopLevel_APIException.html
# Appeasement Class in dw.order class_dw_order_Appeasement.html
# AppeasementItem Class in dw.order class_dw_order_AppeasementItem.html
# ApplePayHookResult Class in dw.extensions.applepay class_dw_extensions_applepay_ApplePayHookResult.html
# ApplePayHooks Class in dw.extensions.applepay class_dw_extensions_applepay_ApplePayHooks.html
# ApproachingDiscount Class in dw.campaign class_dw_campaign_ApproachingDiscount.html
# arguments Class in TopLevel class_TopLevel_arguments.html
# Array Class in TopLevel class_TopLevel_Array.html
# ArrayList Class in dw.util class_dw_util_ArrayList.html
# Assert Class in dw.util class_dw_util_Assert.html
# AuthenticationStatus Class in dw.customer class_dw_customer_AuthenticationStatus.html
# Basket Class in dw.order class_dw_order_Basket.html
# BasketMgr Class in dw.order class_dw_order_BasketMgr.html
# BigInteger Class in dw.util class_dw_util_BigInteger.html
# BonusChoiceDiscount Class in dw.campaign class_dw_campaign_BonusChoiceDiscount.html
# BonusDiscount Class in dw.campaign class_dw_campaign_BonusDiscount.html
# BonusDiscountLineItem Class in dw.order class_dw_order_BonusDiscountLineItem.html
# Boolean Class in TopLevel class_TopLevel_Boolean.html
# BrandSuggestions Class in dw.suggest class_dw_suggest_BrandSuggestions.html
# Bytes Class in dw.util class_dw_util_Bytes.html
# CalculateHooks Class in dw.order.hooks class_dw_order_hooks_CalculateHooks.html
# Calendar Class in dw.util class_dw_util_Calendar.html
# Campaign Class in dw.campaign class_dw_campaign_Campaign.html
# CampaignMgr Class in dw.campaign class_dw_campaign_CampaignMgr.html
# CampaignStatusCodes Class in dw.campaign class_dw_campaign_CampaignStatusCodes.html
# Catalog Class in dw.catalog class_dw_catalog_Catalog.html
# CatalogMgr Class in dw.catalog class_dw_catalog_CatalogMgr.html
# Category Class in dw.catalog class_dw_catalog_Category.html
# CategoryAssignment Class in dw.catalog class_dw_catalog_CategoryAssignment.html
# CategoryLink Class in dw.catalog class_dw_catalog_CategoryLink.html
# CategorySuggestions Class in dw.suggest class_dw_suggest_CategorySuggestions.html
# CertificateRef Class in dw.crypto class_dw_crypto_CertificateRef.html
# Cipher Class in dw.crypto class_dw_crypto_Cipher.html
# ClickStream Class in dw.web class_dw_web_ClickStream.html
# ClickStreamEntry Class in dw.web class_dw_web_ClickStreamEntry.html
# Collection Class in dw.util class_dw_util_Collection.html
# Component Class in dw.experience class_dw_experience_Component.html
# ComponentRenderSettings Class in dw.experience class_dw_experience_ComponentRenderSettings.html
# ComponentScriptContext Class in dw.experience class_dw_experience_ComponentScriptContext.html
# Content Class in dw.content class_dw_content_Content.html
# ContentMgr Class in dw.content class_dw_content_ContentMgr.html
# ContentSearchModel Class in dw.content class_dw_content_ContentSearchModel.html
# ContentSearchRefinementDefinition Class in dw.content class_dw_content_ContentSearchRefinementDefinition.html
# ContentSearchRefinements Class in dw.content class_dw_content_ContentSearchRefinements.html
# ContentSearchRefinementValue Class in dw.content class_dw_content_ContentSearchRefinementValue.html
# ContentSuggestions Class in dw.suggest class_dw_suggest_ContentSuggestions.html
# ConversionError Class in TopLevel class_TopLevel_ConversionError.html
# Cookie Class in dw.web class_dw_web_Cookie.html
# Cookies Class in dw.web class_dw_web_Cookies.html
# Coupon Class in dw.campaign class_dw_campaign_Coupon.html
# CouponLineItem Class in dw.order class_dw_order_CouponLineItem.html
# CouponMgr Class in dw.campaign class_dw_campaign_CouponMgr.html
# CouponRedemption Class in dw.campaign class_dw_campaign_CouponRedemption.html
# CouponStatusCodes Class in dw.campaign class_dw_campaign_CouponStatusCodes.html
# CreateBasketFromOrderException Class in dw.order class_dw_order_CreateBasketFromOrderException.html
# CreateCouponLineItemException Class in dw.order class_dw_order_CreateCouponLineItemException.html
# CreateOrderException Class in dw.order class_dw_order_CreateOrderException.html
# Credentials Class in dw.customer class_dw_customer_Credentials.html
# CSRFProtection Class in dw.web class_dw_web_CSRFProtection.html
# CSVStreamReader Class in dw.io class_dw_io_CSVStreamReader.html
# CSVStreamWriter Class in dw.io class_dw_io_CSVStreamWriter.html
# Currency Class in dw.util class_dw_util_Currency.html
# CustomAttributes Class in dw.object class_dw_object_CustomAttributes.html
# Customer Class in dw.customer class_dw_customer_Customer.html
# CustomerActiveData Class in dw.customer class_dw_customer_CustomerActiveData.html
# CustomerAddress Class in dw.customer class_dw_customer_CustomerAddress.html
# CustomerGroup Class in dw.customer class_dw_customer_CustomerGroup.html
# CustomerList Class in dw.customer class_dw_customer_CustomerList.html
# CustomerMgr Class in dw.customer class_dw_customer_CustomerMgr.html
# CustomerPasswordConstraints Class in dw.customer class_dw_customer_CustomerPasswordConstraints.html
# CustomerPaymentInstrument Class in dw.customer class_dw_customer_CustomerPaymentInstrument.html
# CustomerStatusCodes Class in dw.customer class_dw_customer_CustomerStatusCodes.html
# CustomObject Class in dw.object class_dw_object_CustomObject.html
# CustomObjectMgr Class in dw.object class_dw_object_CustomObjectMgr.html
# CustomSuggestions Class in dw.suggest class_dw_suggest_CustomSuggestions.html
# Date Class in TopLevel class_TopLevel_Date.html
# DateUtils Class in dw.util class_dw_util_DateUtils.html
# Decimal Class in dw.util class_dw_util_Decimal.html
# Discount Class in dw.campaign class_dw_campaign_Discount.html
# DiscountPlan Class in dw.campaign class_dw_campaign_DiscountPlan.html
# Encoding Class in dw.crypto class_dw_crypto_Encoding.html
# EncryptedObject Class in dw.customer class_dw_customer_EncryptedObject.html
# EnumValue Class in dw.value class_dw_value_EnumValue.html
# Error Class in TopLevel class_TopLevel_Error.html
# EvalError Class in TopLevel class_TopLevel_EvalError.html
# Extensible Class in dw.object class_dw_object_Extensible.html
# ExtensibleObject Class in dw.object class_dw_object_ExtensibleObject.html
# ExternalProfile Class in dw.customer class_dw_customer_ExternalProfile.html
# FacebookFeedHooks Class in dw.extensions.facebook class_dw_extensions_facebook_FacebookFeedHooks.html
# FacebookProduct Class in dw.extensions.facebook class_dw_extensions_facebook_FacebookProduct.html
# Fault Class in TopLevel class_TopLevel_Fault.html
# File Class in dw.io class_dw_io_File.html
# FileReader Class in dw.io class_dw_io_FileReader.html
# FileWriter Class in dw.io class_dw_io_FileWriter.html
# FilteringCollection Class in dw.util class_dw_util_FilteringCollection.html
# FixedPriceDiscount Class in dw.campaign class_dw_campaign_FixedPriceDiscount.html
# FixedPriceShippingDiscount Class in dw.campaign class_dw_campaign_FixedPriceShippingDiscount.html
# FocalPoint Class in dw.experience.image class_dw_experience_image_FocalPoint.html
# Folder Class in dw.content class_dw_content_Folder.html
# Form Class in dw.web class_dw_web_Form.html
# FormAction Class in dw.web class_dw_web_FormAction.html
# FormElement Class in dw.web class_dw_web_FormElement.html
# FormElementValidationResult Class in dw.web class_dw_web_FormElementValidationResult.html
# FormField Class in dw.web class_dw_web_FormField.html
# FormFieldOption Class in dw.web class_dw_web_FormFieldOption.html
# FormFieldOptions Class in dw.web class_dw_web_FormFieldOptions.html
# FormGroup Class in dw.web class_dw_web_FormGroup.html
# FormList Class in dw.web class_dw_web_FormList.html
# FormListItem Class in dw.web class_dw_web_FormListItem.html
# Forms Class in dw.web class_dw_web_Forms.html
# FreeDiscount Class in dw.campaign class_dw_campaign_FreeDiscount.html
# FreeShippingDiscount Class in dw.campaign class_dw_campaign_FreeShippingDiscount.html
# FTPClient Class in dw.net class_dw_net_FTPClient.html
# FTPFileInfo Class in dw.net class_dw_net_FTPFileInfo.html
# FTPService Class in dw.svc class_dw_svc_FTPService.html
# FTPServiceDefinition Class in dw.svc class_dw_svc_FTPServiceDefinition.html
# Function Class in TopLevel class_TopLevel_Function.html
# Generator Class in TopLevel class_TopLevel_Generator.html
# Geolocation Class in dw.util class_dw_util_Geolocation.html
# GiftCertificate Class in dw.order class_dw_order_GiftCertificate.html
# GiftCertificateLineItem Class in dw.order class_dw_order_GiftCertificateLineItem.html
# GiftCertificateMgr Class in dw.order class_dw_order_GiftCertificateMgr.html
# GiftCertificateStatusCodes Class in dw.order class_dw_order_GiftCertificateStatusCodes.html
# HashMap Class in dw.util class_dw_util_HashMap.html
# HashSet Class in dw.util class_dw_util_HashSet.html
# HookMgr Class in dw.system class_dw_system_HookMgr.html
# HTTPClient Class in dw.net class_dw_net_HTTPClient.html
# HTTPFormService Class in dw.svc class_dw_svc_HTTPFormService.html
# HTTPFormServiceDefinition Class in dw.svc class_dw_svc_HTTPFormServiceDefinition.html
# HttpParameter Class in dw.web class_dw_web_HttpParameter.html
# HttpParameterMap Class in dw.web class_dw_web_HttpParameterMap.html
# HTTPRequestPart Class in dw.net class_dw_net_HTTPRequestPart.html
# HTTPService Class in dw.svc class_dw_svc_HTTPService.html
# HTTPServiceDefinition Class in dw.svc class_dw_svc_HTTPServiceDefinition.html
# Image Class in dw.experience.image class_dw_experience_image_Image.html
# ImageMetaData Class in dw.experience.image class_dw_experience_image_ImageMetaData.html
# InputStream Class in dw.io class_dw_io_InputStream.html
# InternalError Class in TopLevel class_TopLevel_InternalError.html
# InternalObject Class in dw.system class_dw_system_InternalObject.html
# Invoice Class in dw.order class_dw_order_Invoice.html
# InvoiceItem Class in dw.order class_dw_order_InvoiceItem.html
# IOError Class in TopLevel class_TopLevel_IOError.html
# ISML Class in dw.template class_dw_template_ISML.html
# Iterator Class in TopLevel class_TopLevel_Iterator.html
# Iterator Class in dw.util class_dw_util_Iterator.html
# JobExecution Class in dw.job class_dw_job_JobExecution.html
# JobProcessMonitor Class in dw.system class_dw_system_JobProcessMonitor.html
# JobStepExecution Class in dw.job class_dw_job_JobStepExecution.html
# JSON Class in TopLevel class_TopLevel_JSON.html
# KeyRef Class in dw.crypto class_dw_crypto_KeyRef.html
# Library Class in dw.content class_dw_content_Library.html
# LineItem Class in dw.order class_dw_order_LineItem.html
# LineItemCtnr Class in dw.order class_dw_order_LineItemCtnr.html
# LinkedHashMap Class in dw.util class_dw_util_LinkedHashMap.html
# LinkedHashSet Class in dw.util class_dw_util_LinkedHashSet.html
# List Class in dw.util class_dw_util_List.html
# Locale Class in dw.util class_dw_util_Locale.html
# LocalServiceRegistry Class in dw.svc class_dw_svc_LocalServiceRegistry.html
# Log Class in dw.system class_dw_system_Log.html
# Logger Class in dw.system class_dw_system_Logger.html
# LogNDC Class in dw.system class_dw_system_LogNDC.html
# LoopIterator Class in dw.web class_dw_web_LoopIterator.html
# Mac Class in dw.crypto class_dw_crypto_Mac.html
# Mail Class in dw.net class_dw_net_Mail.html
# Map Class in dw.util class_dw_util_Map.html
# MapEntry Class in dw.util class_dw_util_MapEntry.html
# MappingKey Class in dw.util class_dw_util_MappingKey.html
# MappingMgr Class in dw.util class_dw_util_MappingMgr.html
# MarkupText Class in dw.content class_dw_content_MarkupText.html
# Math Class in TopLevel class_TopLevel_Math.html
# MediaFile Class in dw.content class_dw_content_MediaFile.html
# MessageDigest Class in dw.crypto class_dw_crypto_MessageDigest.html
# MimeEncodedText Class in dw.value class_dw_value_MimeEncodedText.html
# Module Class in TopLevel class_TopLevel_Module.html
# Money Class in dw.value class_dw_value_Money.html
# Namespace Class in TopLevel class_TopLevel_Namespace.html
# Note Class in dw.object class_dw_object_Note.html
# Number Class in TopLevel class_TopLevel_Number.html
# OAuthAccessTokenResponse Class in dw.customer.oauth class_dw_customer_oauth_OAuthAccessTokenResponse.html
# OAuthFinalizedResponse Class in dw.customer.oauth class_dw_customer_oauth_OAuthFinalizedResponse.html
# OAuthLoginFlowMgr Class in dw.customer.oauth class_dw_customer_oauth_OAuthLoginFlowMgr.html
# OAuthUserInfoResponse Class in dw.customer.oauth class_dw_customer_oauth_OAuthUserInfoResponse.html
# Object Class in TopLevel class_TopLevel_Object.html
# ObjectAttributeDefinition Class in dw.object class_dw_object_ObjectAttributeDefinition.html
# ObjectAttributeGroup Class in dw.object class_dw_object_ObjectAttributeGroup.html
# ObjectAttributeValueDefinition Class in dw.object class_dw_object_ObjectAttributeValueDefinition.html
# ObjectTypeDefinition Class in dw.object class_dw_object_ObjectTypeDefinition.html
# Order Class in dw.order class_dw_order_Order.html
# OrderAddress Class in dw.order class_dw_order_OrderAddress.html
# OrderHistory Class in dw.customer class_dw_customer_OrderHistory.html
# OrderHooks Class in dw.order.hooks class_dw_order_hooks_OrderHooks.html
# OrderItem Class in dw.order class_dw_order_OrderItem.html
# OrderMgr Class in dw.order class_dw_order_OrderMgr.html
# OrderPaymentInstrument Class in dw.order class_dw_order_OrderPaymentInstrument.html
# OrderProcessStatusCodes Class in dw.order class_dw_order_OrderProcessStatusCodes.html
# OrganizationPreferences Class in dw.system class_dw_system_OrganizationPreferences.html
# OutputStream Class in dw.io class_dw_io_OutputStream.html
# Page Class in dw.experience class_dw_experience_Page.html
# PageMetaData Class in dw.web class_dw_web_PageMetaData.html
# PageMetaTag Class in dw.web class_dw_web_PageMetaTag.html
# PageMgr Class in dw.experience class_dw_experience_PageMgr.html
# PageScriptContext Class in dw.experience class_dw_experience_PageScriptContext.html
# PagingModel Class in dw.web class_dw_web_PagingModel.html
# PaymentApiHooks Class in dw.extensions.paymentapi class_dw_extensions_paymentapi_PaymentApiHooks.html
# PaymentCard Class in dw.order class_dw_order_PaymentCard.html
# PaymentHooks Class in dw.order.hooks class_dw_order_hooks_PaymentHooks.html
# PaymentInstrument Class in dw.order class_dw_order_PaymentInstrument.html
# PaymentMethod Class in dw.order class_dw_order_PaymentMethod.html
# PaymentMgr Class in dw.order class_dw_order_PaymentMgr.html
# PaymentProcessor Class in dw.order class_dw_order_PaymentProcessor.html
# PaymentRequestHookResult Class in dw.extensions.paymentrequest class_dw_extensions_paymentrequest_PaymentRequestHookResult.html
# PaymentRequestHooks Class in dw.extensions.paymentrequest class_dw_extensions_paymentrequest_PaymentRequestHooks.html
# PaymentStatusCodes Class in dw.order class_dw_order_PaymentStatusCodes.html
# PaymentTransaction Class in dw.order class_dw_order_PaymentTransaction.html
# PercentageDiscount Class in dw.campaign class_dw_campaign_PercentageDiscount.html
# PercentageOptionDiscount Class in dw.campaign class_dw_campaign_PercentageOptionDiscount.html
# PersistentObject Class in dw.object class_dw_object_PersistentObject.html
# PinterestAvailability Class in dw.extensions.pinterest class_dw_extensions_pinterest_PinterestAvailability.html
# PinterestFeedHooks Class in dw.extensions.pinterest class_dw_extensions_pinterest_PinterestFeedHooks.html
# PinterestOrder Class in dw.extensions.pinterest class_dw_extensions_pinterest_PinterestOrder.html
# PinterestOrderHooks Class in dw.extensions.pinterest class_dw_extensions_pinterest_PinterestOrderHooks.html
# PinterestProduct Class in dw.extensions.pinterest class_dw_extensions_pinterest_PinterestProduct.html
# Pipeline Class in dw.system class_dw_system_Pipeline.html
# PipelineDictionary Class in dw.system class_dw_system_PipelineDictionary.html
# Port Class in dw.ws class_dw_ws_Port.html
# PriceAdjustment Class in dw.order class_dw_order_PriceAdjustment.html
# PriceAdjustmentLimitTypes Class in dw.order class_dw_order_PriceAdjustmentLimitTypes.html
# PriceBook Class in dw.catalog class_dw_catalog_PriceBook.html
# PriceBookMgr Class in dw.catalog class_dw_catalog_PriceBookMgr.html
# PriceBookPriceDiscount Class in dw.campaign class_dw_campaign_PriceBookPriceDiscount.html
# PrintWriter Class in dw.io class_dw_io_PrintWriter.html
# Product Class in dw.catalog class_dw_catalog_Product.html
# ProductActiveData Class in dw.catalog class_dw_catalog_ProductActiveData.html
# ProductAttributeModel Class in dw.catalog class_dw_catalog_ProductAttributeModel.html
# ProductAvailabilityLevels Class in dw.catalog class_dw_catalog_ProductAvailabilityLevels.html
# ProductAvailabilityModel Class in dw.catalog class_dw_catalog_ProductAvailabilityModel.html
# ProductInventoryList Class in dw.catalog class_dw_catalog_ProductInventoryList.html
# ProductInventoryMgr Class in dw.catalog class_dw_catalog_ProductInventoryMgr.html
# ProductInventoryRecord Class in dw.catalog class_dw_catalog_ProductInventoryRecord.html
# ProductLineItem Class in dw.order class_dw_order_ProductLineItem.html
# ProductLink Class in dw.catalog class_dw_catalog_ProductLink.html
# ProductList Class in dw.customer class_dw_customer_ProductList.html
# ProductListItem Class in dw.customer class_dw_customer_ProductListItem.html
# ProductListItemPurchase Class in dw.customer class_dw_customer_ProductListItemPurchase.html
# ProductListMgr Class in dw.customer class_dw_customer_ProductListMgr.html
# ProductListRegistrant Class in dw.customer class_dw_customer_ProductListRegistrant.html
# ProductMgr Class in dw.catalog class_dw_catalog_ProductMgr.html
# ProductOption Class in dw.catalog class_dw_catalog_ProductOption.html
# ProductOptionModel Class in dw.catalog class_dw_catalog_ProductOptionModel.html
# ProductOptionValue Class in dw.catalog class_dw_catalog_ProductOptionValue.html
# ProductPriceInfo Class in dw.catalog class_dw_catalog_ProductPriceInfo.html
# ProductPriceModel Class in dw.catalog class_dw_catalog_ProductPriceModel.html
# ProductPriceTable Class in dw.catalog class_dw_catalog_ProductPriceTable.html
# ProductSearchHit Class in dw.catalog class_dw_catalog_ProductSearchHit.html
# ProductSearchModel Class in dw.catalog class_dw_catalog_ProductSearchModel.html
# ProductSearchRefinementDefinition Class in dw.catalog class_dw_catalog_ProductSearchRefinementDefinition.html
# ProductSearchRefinements Class in dw.catalog class_dw_catalog_ProductSearchRefinements.html
# ProductSearchRefinementValue Class in dw.catalog class_dw_catalog_ProductSearchRefinementValue.html
# ProductShippingCost Class in dw.order class_dw_order_ProductShippingCost.html
# ProductShippingLineItem Class in dw.order class_dw_order_ProductShippingLineItem.html
# ProductShippingModel Class in dw.order class_dw_order_ProductShippingModel.html
# ProductSuggestions Class in dw.suggest class_dw_suggest_ProductSuggestions.html
# ProductVariationAttribute Class in dw.catalog class_dw_catalog_ProductVariationAttribute.html
# ProductVariationAttributeValue Class in dw.catalog class_dw_catalog_ProductVariationAttributeValue.html
# ProductVariationModel Class in dw.catalog class_dw_catalog_ProductVariationModel.html
# Profile Class in dw.customer class_dw_customer_Profile.html
# Promotion Class in dw.campaign class_dw_campaign_Promotion.html
# PromotionMgr Class in dw.campaign class_dw_campaign_PromotionMgr.html
# PromotionPlan Class in dw.campaign class_dw_campaign_PromotionPlan.html
# PropertyComparator Class in dw.util class_dw_util_PropertyComparator.html
# QName Class in TopLevel class_TopLevel_QName.html
# Quantity Class in dw.value class_dw_value_Quantity.html
# RandomAccessFileReader Class in dw.io class_dw_io_RandomAccessFileReader.html
# RangeError Class in TopLevel class_TopLevel_RangeError.html
# Reader Class in dw.io class_dw_io_Reader.html
# Recommendation Class in dw.catalog class_dw_catalog_Recommendation.html
# ReferenceError Class in TopLevel class_TopLevel_ReferenceError.html
# RegExp Class in TopLevel class_TopLevel_RegExp.html
# Region Class in dw.experience class_dw_experience_Region.html
# RegionRenderSettings Class in dw.experience class_dw_experience_RegionRenderSettings.html
# Request Class in dw.system class_dw_system_Request.html
# RequestHooks Class in dw.system class_dw_system_RequestHooks.html
# Resource Class in dw.web class_dw_web_Resource.html
# Response Class in dw.system class_dw_system_Response.html
# Result Class in dw.svc class_dw_svc_Result.html
# Return Class in dw.order class_dw_order_Return.html
# ReturnCase Class in dw.order class_dw_order_ReturnCase.html
# ReturnCaseItem Class in dw.order class_dw_order_ReturnCaseItem.html
# ReturnHooks Class in dw.order.hooks class_dw_order_hooks_ReturnHooks.html
# ReturnItem Class in dw.order class_dw_order_ReturnItem.html
# SearchModel Class in dw.catalog class_dw_catalog_SearchModel.html
# SearchPhraseSuggestions Class in dw.suggest class_dw_suggest_SearchPhraseSuggestions.html
# SearchRefinementDefinition Class in dw.catalog class_dw_catalog_SearchRefinementDefinition.html
# SearchRefinements Class in dw.catalog class_dw_catalog_SearchRefinements.html
# SearchRefinementValue Class in dw.catalog class_dw_catalog_SearchRefinementValue.html
# SecureEncoder Class in dw.util class_dw_util_SecureEncoder.html
# SecureFilter Class in dw.util class_dw_util_SecureFilter.html
# SecureRandom Class in dw.crypto class_dw_crypto_SecureRandom.html
# SeekableIterator Class in dw.util class_dw_util_SeekableIterator.html
# Service Class in dw.svc class_dw_svc_Service.html
# ServiceCallback Class in dw.svc class_dw_svc_ServiceCallback.html
# ServiceConfig Class in dw.svc class_dw_svc_ServiceConfig.html
# ServiceCredential Class in dw.svc class_dw_svc_ServiceCredential.html
# ServiceDefinition Class in dw.svc class_dw_svc_ServiceDefinition.html
# ServiceProfile Class in dw.svc class_dw_svc_ServiceProfile.html
# ServiceRegistry Class in dw.svc class_dw_svc_ServiceRegistry.html
# Session Class in dw.system class_dw_system_Session.html
# Set Class in dw.util class_dw_util_Set.html
# SFTPClient Class in dw.net class_dw_net_SFTPClient.html
# SFTPFileInfo Class in dw.net class_dw_net_SFTPFileInfo.html
# Shipment Class in dw.order class_dw_order_Shipment.html
# ShipmentShippingCost Class in dw.order class_dw_order_ShipmentShippingCost.html
# ShipmentShippingModel Class in dw.order class_dw_order_ShipmentShippingModel.html
# ShippingLineItem Class in dw.order class_dw_order_ShippingLineItem.html
# ShippingLocation Class in dw.order class_dw_order_ShippingLocation.html
# ShippingMethod Class in dw.order class_dw_order_ShippingMethod.html
# ShippingMgr Class in dw.order class_dw_order_ShippingMgr.html
# ShippingOrder Class in dw.order class_dw_order_ShippingOrder.html
# ShippingOrderHooks Class in dw.order.hooks class_dw_order_hooks_ShippingOrderHooks.html
# ShippingOrderItem Class in dw.order class_dw_order_ShippingOrderItem.html
# Signature Class in dw.crypto class_dw_crypto_Signature.html
# SimpleExtensible Class in dw.object class_dw_object_SimpleExtensible.html
# Site Class in dw.system class_dw_system_Site.html
# SitemapFile Class in dw.sitemap class_dw_sitemap_SitemapFile.html
# SitemapMgr Class in dw.sitemap class_dw_sitemap_SitemapMgr.html
# SitePreferences Class in dw.system class_dw_system_SitePreferences.html
# SlotContent Class in dw.campaign class_dw_campaign_SlotContent.html
# SOAPService Class in dw.svc class_dw_svc_SOAPService.html
# SOAPServiceDefinition Class in dw.svc class_dw_svc_SOAPServiceDefinition.html
# SOAPUtil Class in dw.rpc class_dw_rpc_SOAPUtil.html
# SortedMap Class in dw.util class_dw_util_SortedMap.html
# SortedSet Class in dw.util class_dw_util_SortedSet.html
# SortingOption Class in dw.catalog class_dw_catalog_SortingOption.html
# SortingRule Class in dw.catalog class_dw_catalog_SortingRule.html
# SourceCodeGroup Class in dw.campaign class_dw_campaign_SourceCodeGroup.html
# SourceCodeInfo Class in dw.campaign class_dw_campaign_SourceCodeInfo.html
# SourceCodeStatusCodes Class in dw.campaign class_dw_campaign_SourceCodeStatusCodes.html
# Status Class in dw.system class_dw_system_Status.html
# StatusItem Class in dw.system class_dw_system_StatusItem.html
# StopIteration Class in TopLevel class_TopLevel_StopIteration.html
# Store Class in dw.catalog class_dw_catalog_Store.html
# StoreGroup Class in dw.catalog class_dw_catalog_StoreGroup.html
# StoreMgr Class in dw.catalog class_dw_catalog_StoreMgr.html
# String Class in TopLevel class_TopLevel_String.html
# StringUtils Class in dw.util class_dw_util_StringUtils.html
# StringWriter Class in dw.io class_dw_io_StringWriter.html
# Stub Class in dw.rpc class_dw_rpc_Stub.html
# SuggestedCategory Class in dw.suggest class_dw_suggest_SuggestedCategory.html
# SuggestedContent Class in dw.suggest class_dw_suggest_SuggestedContent.html
# SuggestedPhrase Class in dw.suggest class_dw_suggest_SuggestedPhrase.html
# SuggestedProduct Class in dw.suggest class_dw_suggest_SuggestedProduct.html
# SuggestedTerm Class in dw.suggest class_dw_suggest_SuggestedTerm.html
# SuggestedTerms Class in dw.suggest class_dw_suggest_SuggestedTerms.html
# Suggestions Class in dw.suggest class_dw_suggest_Suggestions.html
# SuggestModel Class in dw.suggest class_dw_suggest_SuggestModel.html
# SumItem Class in dw.order class_dw_order_SumItem.html
# SyntaxError Class in TopLevel class_TopLevel_SyntaxError.html
# System Class in dw.system class_dw_system_System.html
# SystemError Class in TopLevel class_TopLevel_SystemError.html
# SystemObjectMgr Class in dw.object class_dw_object_SystemObjectMgr.html
# TaxGroup Class in dw.order class_dw_order_TaxGroup.html
# TaxItem Class in dw.order class_dw_order_TaxItem.html
# TaxMgr Class in dw.order class_dw_order_TaxMgr.html
# Template Class in dw.util class_dw_util_Template.html
# TotalFixedPriceDiscount Class in dw.campaign class_dw_campaign_TotalFixedPriceDiscount.html
# TrackingInfo Class in dw.order class_dw_order_TrackingInfo.html
# TrackingRef Class in dw.order class_dw_order_TrackingRef.html
# Transaction Class in dw.system class_dw_system_Transaction.html
# TypeError Class in TopLevel class_TopLevel_TypeError.html
# URIError Class in TopLevel class_TopLevel_URIError.html
# URL Class in dw.web class_dw_web_URL.html
# URLAction Class in dw.web class_dw_web_URLAction.html
# URLParameter Class in dw.web class_dw_web_URLParameter.html
# URLRedirect Class in dw.web class_dw_web_URLRedirect.html
# URLRedirectMgr Class in dw.web class_dw_web_URLRedirectMgr.html
# URLUtils Class in dw.web class_dw_web_URLUtils.html
# UUIDUtils Class in dw.util class_dw_util_UUIDUtils.html
# Variant Class in dw.catalog class_dw_catalog_Variant.html
# VariationGroup Class in dw.catalog class_dw_catalog_VariationGroup.html
# Velocity Class in dw.template class_dw_template_Velocity.html
# Wallet Class in dw.customer class_dw_customer_Wallet.html
# WebDAVClient Class in dw.net class_dw_net_WebDAVClient.html
# WebDAVFileInfo Class in dw.net class_dw_net_WebDAVFileInfo.html
# WebReference Class in dw.rpc class_dw_rpc_WebReference.html
# WebReference2 Class in dw.ws class_dw_ws_WebReference2.html
# Writer Class in dw.io class_dw_io_Writer.html
# WSUtil Class in dw.ws class_dw_ws_WSUtil.html
# XML Class in TopLevel class_TopLevel_XML.html
# XMLIndentingStreamWriter Class in dw.io class_dw_io_XMLIndentingStreamWriter.html
# XMLList Class in TopLevel class_TopLevel_XMLList.html
# XMLStreamConstants Class in dw.io class_dw_io_XMLStreamConstants.html
# XMLStreamError Class in TopLevel class_TopLevel_XMLStreamError.html
# XMLStreamReader Class in dw.io class_dw_io_XMLStreamReader.html
# XMLStreamWriter Class in dw.io class_dw_io_XMLStreamWriter.html

# %% [markdown]
# # Pipelet API

# %%
if os.path.exists("./DWREApiDoc.docset/Contents/Resources/Documents/pipelet/"):
    shutil.rmtree("./DWREApiDoc.docset/Contents/Resources/Documents/pipelet/")
shutil.copytree("./dwredocs/pipeletapi/html/api/", "./DWREApiDoc.docset/Contents/Resources/Documents/pipelet")
# Out:
# './DWREApiDoc.docset/Contents/Resources/Documents/pipelet'

# %%
with open("./DWREApiDoc.docset/Contents/Resources/Documents/pipelet/pipeletList.html", "r") as f:
    d = pq(f.read())

c = conn.cursor()

for link in d('.classesName a'):
    name = link.find("span").text
    path = link.attrib["href"]
    
    print(name, path)
    
    c.execute("INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('%s', 'Procedure', '%s');" % 
              (name, "pipelet/%s" % path))
    
conn.commit()
# Out:
# ABCTest pipelet.ABCTest.html
# AcceptForm pipelet.AcceptForm.html
# AddBonusProductToBasket pipelet.AddBonusProductToBasket.html
# AddCouponToBasket pipelet.AddCouponToBasket.html
# AddCouponToBasket2 pipelet.AddCouponToBasket2.html
# AddGiftCertificateToBasket pipelet.AddGiftCertificateToBasket.html
# AddGiftCertificateToProductList pipelet.AddGiftCertificateToProductList.html
# AddPaymentInstrumentToBasket pipelet.AddPaymentInstrumentToBasket.html
# AddProductToBasket pipelet.AddProductToBasket.html
# AddProductToProductList pipelet.AddProductToProductList.html
# Assign pipelet.Assign.html
# CancelOrder pipelet.CancelOrder.html
# ClearFormElement pipelet.ClearFormElement.html
# CreateBasketForOrderEdit pipelet.CreateBasketForOrderEdit.html
# CreateBasketPaymentInstrument pipelet.CreateBasketPaymentInstrument.html
# CreateBillingAddress pipelet.CreateBillingAddress.html
# CreateCustomer pipelet.CreateCustomer.html
# CreateCustomerAddress pipelet.CreateCustomerAddress.html
# CreateCustomerPaymentInstrument pipelet.CreateCustomerPaymentInstrument.html
# CreateCustomerProfile pipelet.CreateCustomerProfile.html
# CreateCustomObject pipelet.CreateCustomObject.html
# CreateGiftCertificate pipelet.CreateGiftCertificate.html
# CreateOrder pipelet.CreateOrder.html
# CreateOrder2 pipelet.CreateOrder2.html
# CreateOrderNo pipelet.CreateOrderNo.html
# CreatePaymentTransaction pipelet.CreatePaymentTransaction.html
# CreateProductList pipelet.CreateProductList.html
# CreateProductListRegistrant pipelet.CreateProductListRegistrant.html
# CreateShipment pipelet.CreateShipment.html
# CreateShippingAddress pipelet.CreateShippingAddress.html
# CreateShippingOrders pipelet.CreateShippingOrders.html
# Eval pipelet.Eval.html
# ExportABTests pipelet.ExportABTests.html
# ExportCatalog pipelet.ExportCatalog.html
# ExportContent pipelet.ExportContent.html
# ExportCouponCodes pipelet.ExportCouponCodes.html
# ExportCoupons pipelet.ExportCoupons.html
# ExportCustomerGroups pipelet.ExportCustomerGroups.html
# ExportCustomerList pipelet.ExportCustomerList.html
# ExportCustomers pipelet.ExportCustomers.html
# ExportCustomObjects pipelet.ExportCustomObjects.html
# ExportGiftCertificates pipelet.ExportGiftCertificates.html
# ExportInventoryLists pipelet.ExportInventoryLists.html
# ExportMetaData pipelet.ExportMetaData.html
# ExportOrders pipelet.ExportOrders.html
# ExportPriceAdjustmentLimits pipelet.ExportPriceAdjustmentLimits.html
# ExportPriceBooks pipelet.ExportPriceBooks.html
# ExportProductLists pipelet.ExportProductLists.html
# ExportPromotions pipelet.ExportPromotions.html
# ExportShippingMethods pipelet.ExportShippingMethods.html
# ExportSlots pipelet.ExportSlots.html
# ExportSourceCodes pipelet.ExportSourceCodes.html
# ExportStores pipelet.ExportStores.html
# ExportTaxTable pipelet.ExportTaxTable.html
# FailOrder pipelet.FailOrder.html
# FinalizeOAuthLogin pipelet.FinalizeOAuthLogin.html
# GenerateResetPasswordToken pipelet.GenerateResetPasswordToken.html
# GetBasket pipelet.GetBasket.html
# GetBrands pipelet.GetBrands.html
# GetCategory pipelet.GetCategory.html
# GetContent pipelet.GetContent.html
# GetCustomer pipelet.GetCustomer.html
# GetCustomerAddress pipelet.GetCustomerAddress.html
# GetCustomerPaymentInstruments pipelet.GetCustomerPaymentInstruments.html
# GetCustomerProfile pipelet.GetCustomerProfile.html
# GetGiftCertificate pipelet.GetGiftCertificate.html
# GetLastVisitedProducts pipelet.GetLastVisitedProducts.html
# GetNearestStores pipelet.GetNearestStores.html
# GetOrder pipelet.GetOrder.html
# GetPaymentProcessor pipelet.GetPaymentProcessor.html
# GetProduct pipelet.GetProduct.html
# GetProductList pipelet.GetProductList.html
# GetProductLists pipelet.GetProductLists.html
# GetReplicationStatus pipelet.GetReplicationStatus.html
# GetSearchSuggestions pipelet.GetSearchSuggestions.html
# ImportABTests pipelet.ImportABTests.html
# ImportActiveData pipelet.ImportActiveData.html
# ImportCampaigns pipelet.ImportCampaigns.html
# ImportCatalog pipelet.ImportCatalog.html
# ImportContent pipelet.ImportContent.html
# ImportCoupons pipelet.ImportCoupons.html
# ImportCustomerGroups pipelet.ImportCustomerGroups.html
# ImportCustomerList pipelet.ImportCustomerList.html
# ImportCustomers pipelet.ImportCustomers.html
# ImportCustomObjects pipelet.ImportCustomObjects.html
# ImportGiftCertificates pipelet.ImportGiftCertificates.html
# ImportInventoryLists pipelet.ImportInventoryLists.html
# ImportKeyValueMapping pipelet.ImportKeyValueMapping.html
# ImportPriceAdjustmentLimits pipelet.ImportPriceAdjustmentLimits.html
# ImportPriceBooks pipelet.ImportPriceBooks.html
# ImportProductLists pipelet.ImportProductLists.html
# ImportPromotions pipelet.ImportPromotions.html
# ImportShippingMethods pipelet.ImportShippingMethods.html
# ImportSlots pipelet.ImportSlots.html
# ImportSourceCodes pipelet.ImportSourceCodes.html
# ImportStores pipelet.ImportStores.html
# ImportTaxTable pipelet.ImportTaxTable.html
# InitiateOAuthLogin pipelet.InitiateOAuthLogin.html
# InvalidateFormElement pipelet.InvalidateFormElement.html
# InvalidateWebCache pipelet.InvalidateWebCache.html
# LoginAgentUser pipelet.LoginAgentUser.html
# LoginCustomer pipelet.LoginCustomer.html
# LoginOnBehalfCustomer pipelet.LoginOnBehalfCustomer.html
# LogoutAgentUser pipelet.LogoutAgentUser.html
# LogoutCustomer pipelet.LogoutCustomer.html
# Paging pipelet.Paging.html
# PlaceOrder pipelet.PlaceOrder.html
# RedeemGiftCertificate pipelet.RedeemGiftCertificate.html
# RedirectURL pipelet.RedirectURL.html
# RemoveBasketPaymentInstrument pipelet.RemoveBasketPaymentInstrument.html
# RemoveCouponLineItem pipelet.RemoveCouponLineItem.html
# RemoveCustomer pipelet.RemoveCustomer.html
# RemoveCustomerAddress pipelet.RemoveCustomerAddress.html
# RemoveCustomerPaymentInstrument pipelet.RemoveCustomerPaymentInstrument.html
# RemoveCustomObject pipelet.RemoveCustomObject.html
# RemoveGiftCertificateLineItem pipelet.RemoveGiftCertificateLineItem.html
# RemoveProductLineItem pipelet.RemoveProductLineItem.html
# RemoveProductList pipelet.RemoveProductList.html
# RemoveProductListItem pipelet.RemoveProductListItem.html
# ReplaceLineItemProduct pipelet.ReplaceLineItemProduct.html
# ReserveInventoryForOrder pipelet.ReserveInventoryForOrder.html
# ResetCustomerPassword pipelet.ResetCustomerPassword.html
# ResetCustomerPasswordWithToken pipelet.ResetCustomerPasswordWithToken.html
# ReturnImport pipelet.ReturnImport.html
# RunJobNow pipelet.RunJobNow.html
# Script pipelet.Script.html
# Search pipelet.Search.html
# SearchCustomObject pipelet.SearchCustomObject.html
# SearchProductLists pipelet.SearchProductLists.html
# SearchRedirectURL pipelet.SearchRedirectURL.html
# SearchSystemObject pipelet.SearchSystemObject.html
# SendGoogleSiteMap pipelet.SendGoogleSiteMap.html
# SendMail pipelet.SendMail.html
# SetApplicablePriceBooks pipelet.SetApplicablePriceBooks.html
# SetCustomerPassword pipelet.SetCustomerPassword.html
# SetFormOptions pipelet.SetFormOptions.html
# SetRequestLocale pipelet.SetRequestLocale.html
# SetSessionCurrency pipelet.SetSessionCurrency.html
# SetShippingMethod pipelet.SetShippingMethod.html
# SetSourceCode pipelet.SetSourceCode.html
# SourceCodeRedirectURL pipelet.SourceCodeRedirectURL.html
# StartCheckout pipelet.StartCheckout.html
# TriggerReplication pipelet.TriggerReplication.html
# UpdateFormWithObject pipelet.UpdateFormWithObject.html
# UpdateObjectWithForm pipelet.UpdateObjectWithForm.html
# UpdatePageMetaData pipelet.UpdatePageMetaData.html
# UpdateProductLineItemQuantity pipelet.UpdateProductLineItemQuantity.html
# UpdateProductOptionSelections pipelet.UpdateProductOptionSelections.html
# UpdateProductVariationSelections pipelet.UpdateProductVariationSelections.html
# UpdateSearchIndex pipelet.UpdateSearchIndex.html
# UpdateShippingOrders pipelet.UpdateShippingOrders.html
# ValidateActiveDataFile pipelet.ValidateActiveDataFile.html
# ValidateResetPasswordToken pipelet.ValidateResetPasswordToken.html
# ValidateXMLFile pipelet.ValidateXMLFile.html
# VerifyCreditCard pipelet.VerifyCreditCard.html
# VerifyCreditCardExpirationDate pipelet.VerifyCreditCardExpirationDate.html
# VerifyCreditCardNumber pipelet.VerifyCreditCardNumber.html
# VerifyPaymentCard pipelet.VerifyPaymentCard.html
# VSAuthorizeCreditCard pipelet.VSAuthorizeCreditCard.html

# %% [markdown]
# # Pipelet API

# %%
if os.path.exists("./DWREApiDoc.docset/Contents/Resources/Documents/pipelet/"):
    shutil.rmtree("./DWREApiDoc.docset/Contents/Resources/Documents/pipelet/")
shutil.copytree("./dwredocs/pipeletapi/html/api/", "./DWREApiDoc.docset/Contents/Resources/Documents/pipelet")
# Out:
# './DWREApiDoc.docset/Contents/Resources/Documents/pipelet'

# %% [markdown]
# # Sample/Guides

# %%
with open('./dwredocs/guidetemplate.html', 'r') as f:
    template_src = f.read()
template = Template(template_src)

if not os.path.exists('./DWREApiDoc.docset/Contents/Resources/Documents/guides/'):
    os.makedirs('./DWREApiDoc.docset/Contents/Resources/Documents/guides/')
    
for f in os.listdir('./dwredocs/guides/'):
    name, ext = os.path.splitext(f)
    print(name)
    c.execute("INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('%s', 'Guide', '%s');" % 
              (name, "guides/%s" % (name+".html")))
    
    with open('./dwredocs/guides/' + f, 'r') as f:
        doc_output = markdown.markdown(f.read(), extensions=[TableExtension(), FencedCodeExtension(), CodeHiliteExtension()])

    with open(os.path.join('./DWREApiDoc.docset/Contents/Resources/Documents/guides/', name+".html"), 'w') as f:
        output = template.render(body=doc_output)
        f.write(output)

conn.commit()
# Out:
# hooks

# %% [markdown]
# # ISML Tags

# %%
if not os.path.exists('./DWREApiDoc.docset/Contents/Resources/Documents/isml/'):
    os.makedirs('./DWREApiDoc.docset/Contents/Resources/Documents/isml/')
    
for f in os.listdir('./dwredocs/isml/'):
    name, ext = os.path.splitext(f)
    print(name)
    c.execute("INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('%s', 'Tag', '%s');" % 
              (name, "isml/%s" % (name+".html")))
    
    shutil.copy('./dwredocs/isml/' + f, './DWREApiDoc.docset/Contents/Resources/Documents/isml/' + f)

conn.commit()
# Out:
# isactivedatacontext
# isif

# %% [markdown]
# # Schemas

# %%
with open('./dwredocs/schematemplate.html', 'r') as f:
    template_src = f.read()
template = Template(template_src)

if not os.path.exists('./DWREApiDoc.docset/Contents/Resources/Documents/schemas/'):
    os.makedirs('./DWREApiDoc.docset/Contents/Resources/Documents/schemas/')
for f in os.listdir('./dwredocs/xsd/'):
    name, ext = os.path.splitext(f)
    if ext != ".xsd":
        continue
    print(name)
    c.execute("INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('%s', 'Protocol', '%s');" % 
              (f, "schemas/%s" % (name+".html")))
    
    with open('./dwredocs/xsd/' + f, 'r') as f:
        md = """
```xml
# %s
```
        """ % f.read()
        doc_output = markdown.markdown(md, extensions=[TableExtension(), FencedCodeExtension(), CodeHiliteExtension()])

    with open(os.path.join('./DWREApiDoc.docset/Contents/Resources/Documents/schemas/', name+".html"), 'w') as f:
        output = template.render(body=doc_output, name=name)
        f.write(output)

conn.commit()
# Out:
# abtest
# sitemapconfiguration
# jobs
# cachesettings
# sort
# schedules
# customeractivedata
# geolocation
# tax
# csrfwhitelists
# shippingorderupdatefeed
# customobject
# customer
# pagemetatag
# site
# sourcecode
# coupon
# preferences
# couponredemption
# form
# bmext
# pricebook
# paymentprocessor
# returnimportfeed
# customerlist2
# urlrules
# store
# customercdnsettings
# order
# inventory
# shipping
# productlist
# search2
# customerpaymentinstrument
# catalog
# priceadjustmentlimits
# paymentmethod
# feed
# redirecturl
# search
# locales
# xml
# metadata
# slot
# customerlist
# abtestparticipants
# giftcertificate
# library
# promotion
# customergroup
# oauth
# dcext
# services

# %% [markdown]
# ## OCAPI

# %% [markdown]
# Place the cookies from chrome (in normal cookie header format) in .cookies

# %%
OCAPI_PREFIX = '/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/'
OCAPI_INDICIES = [
    'https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Resources/index.html',
    'https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Resources/index.html',
    'https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/usage/APIUsage.html?cp=0_12_2',
    'https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/index.html',
    'https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/index.html'
]

# %%
from lxml import etree as ET
from io import StringIO

# %%
NS = "{http://www.w3.org/1999/xhtml}"
NSMAP = {
    "X" : "http://www.w3.org/1999/xhtml"
}
from urllib.parse import urlparse
LINKS = set()
for page in OCAPI_INDICIES:
    r = requests.get(page)
    content = r.content.decode('utf-8').replace('self == top', 'self == "blah"').encode('utf-8')
    parser = ET.HTMLParser()
    content = ET.fromstring(content, parser)
    parsed_url = urlparse(page)
    dirname = os.path.normpath(os.path.dirname(parsed_url.path))
    if OCAPI_PREFIX not in dirname:
        continue

    for link in content.xpath("//a", namespaces=NSMAP):
        href = link.attrib['href']
        normalized = os.path.normpath(os.path.join(dirname, href))
        full_link = urlparse(f"{parsed_url.scheme}://{parsed_url.netloc}{normalized}")
        full_link = f"{full_link.scheme}://{full_link.netloc}{full_link.path}"
        if OCAPI_PREFIX not in full_link:
            continue
        print(full_link)
        if full_link.endswith('.html'):
            LINKS.add(full_link)
            
resp = requests.get('https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/css/commonltr.css')
css = f"""<style>
{resp.content.decode('utf-8')}
</style>"""
# Out:
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Resources/Ai.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Resources/Baskets.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Resources/Categories.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Resources/Content.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Resources/ContentSearch.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Resources/CustomObjects.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Resources/Customers.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Resources/Folders.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Resources/GiftCertificate.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Resources/OrderSearch.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Resources/Orders.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Resources/PriceAdjustmentLimits.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Resources/ProductLists.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Resources/ProductSearch.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Resources/Products.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Resources/Promotions.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Resources/SearchSuggestion.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Resources/Sessions.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Resources/Site.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Resources/Stores.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Resources/
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Resources/
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Resources/AbTestSearch.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Resources/AbTests.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Resources/CampaignSearch.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Resources/Campaigns.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Resources/CatalogSearch.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Resources/Catalogs.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Resources/Categories.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Resources/CategoryLinks.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Resources/CategoryProductAssignmentSearch.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Resources/CategorySearch.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Resources/CodeVersions.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Resources/CouponRedemptionSearch.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Resources/CouponSearch.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Resources/Coupons.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Resources/CustomObjectDefinitions.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Resources/CustomObjects.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Resources/CustomObjectsSearch.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Resources/CustomerGroupSearch.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Resources/CustomerGroups.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Resources/CustomerLists.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Resources/GiftCertificateSearch.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Resources/GiftCertificates.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Resources/GlobalPreferences.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Resources/InventoryListSearch.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Resources/InventoryLists.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Resources/JobExecutionSearch.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Resources/Jobs.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Resources/Libraries.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Resources/LocaleInfo.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Resources/LogRequests.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Resources/Permissions.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Resources/ProductInventoryRecords.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Resources/ProductSearch.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Resources/Products.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Resources/PromotionCampaignAssignmentSearch.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Resources/PromotionSearch.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Resources/Promotions.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Resources/RoleSearch.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Resources/Roles.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Resources/Settings.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Resources/SitePreferences.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Resources/SiteSearch.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Resources/Sites.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Resources/SlotConfigurationCampaignAssignmentSearch.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Resources/SlotConfigurationSearch.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Resources/SlotConfigurations.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Resources/SlotSearch.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Resources/Slots.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Resources/SortingRuleSearch.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Resources/SourceCodeGroupSearch.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Resources/SourceCodeGroups.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Resources/StoreSearch.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Resources/Stores.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Resources/SystemObjectDefinitionSearch.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Resources/SystemObjectDefinitions.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Resources/UserSearch.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Resources/Users.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Resources/VariantSearch.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Resources/
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Resources/
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/usage/OpenCommerceAPI.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/usage/APIExplorer.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/usage/BatchRequests.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/usage/BestPractices.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/usage/Caching.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/usage/ClientApplicationIdentification.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/usage/CORS.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/usage/CustomProperties.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/usage/Customization.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/usage/DataFormats.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/usage/Expansions.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/usage/Filtering.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/usage/Flash.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/usage/Exceptions.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/usage/HttpHeaders.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/usage/Hooks.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/usage/HttpMethods.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/usage/HttpStatusCodesAndFaults.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/usage/Images.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/usage/JSONP.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/usage/JWT.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/usage/Localization.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/usage/Metadata.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/usage/OAuth.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/usage/OCAPISettings.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/usage/OptimisticLocking.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/usage/Pagination.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/usage/PropertySelection.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/usage/ResourceStates.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/usage/SessionBridge.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/usage/SystemJobs.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/usage/UrlSchema.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/usage/VersioningAndDeprecationPolicy.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/usage/APIExplorer.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/usage/BatchRequests.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/usage/BestPractices.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/usage/Caching.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/usage/ClientApplicationIdentification.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/usage/CORS.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/usage/Customization.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/usage/CustomProperties.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/usage/DataFormats.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/usage/Expansions.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/usage/Filtering.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/usage/Flash.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/usage/Exceptions.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/usage/HttpHeaders.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/usage/Hooks.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/usage/HttpMethods.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/usage/HttpStatusCodesAndFaults.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/usage/Images.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/usage/JSONP.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/usage/JWT.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/usage/Localization.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/usage/Metadata.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/usage/OAuth.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/usage/OCAPISettings.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/usage/OptimisticLocking.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/usage/Pagination.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/usage/PropertySelection.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/usage/ResourceStates.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/usage/SessionBridge.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/usage/SystemJobs.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/usage/UrlSchema.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/usage/VersioningAndDeprecationPolicy.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/usage/
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/usage/
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/ActivityRequest.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/ActivityResult.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/AiProduct.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/ApproachingDiscount.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/ApproachingDiscountResult.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/AuthRequest.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/Basket.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/BasketCreateRequest.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/BasketPaymentInstrumentRequest.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/BasketReference.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/BasketsResult.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/BonusDiscountLineItem.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/BundledProduct.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/BundledProductItem.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/Category.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/CategoryResult.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/Content.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/ContentFolder.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/ContentFolderResult.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/ContentResult.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/ContentSearchRefinement.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/ContentSearchRefinementValue.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/ContentSearchResult.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/CouponItem.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/CustomObject.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/Customer.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/CustomerAddress.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/CustomerAddressLink.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/CustomerAddressResult.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/CustomerInfo.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/CustomerOrderResult.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/CustomerPaymentCardRequest.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/CustomerPaymentInstrument.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/CustomerPaymentInstrumentRequest.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/CustomerPaymentInstrumentResult.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/CustomerProductList.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/CustomerProductListItem.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/CustomerProductListItemLink.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/CustomerProductListItemPurchase.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/CustomerProductListItemPurchaseResult.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/CustomerProductListItemResult.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/CustomerProductListRegistrant.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/CustomerProductListResult.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/CustomerRegistration.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/Discount.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/DiscountRequest.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/Fault.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/Flash.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/GiftCertificate.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/GiftCertificateItem.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/GiftCertificateRequest.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/Image.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/ImageGroup.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/Inventory.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/ItemKey.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/Locale.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/Master.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/Note.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/NotesResult.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/Option.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/OptionItem.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/OptionValue.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/Order.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/OrderAddress.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/OrderPaymentCardRequest.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/OrderPaymentInstrument.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/OrderPaymentInstrumentRequest.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/OrderSearchHit.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/OrderSearchRequest.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/OrderSearchResult.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/PasswordChangeRequest.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/PasswordReset.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/PaymentBankAccount.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/PaymentBankAccountRequest.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/PaymentCard.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/PaymentCardRequest.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/PaymentCardSpec.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/PaymentMethod.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/PaymentMethodResult.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/PriceAdjustment.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/PriceAdjustmentLimit.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/PriceAdjustmentLimits.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/PriceAdjustmentRequest.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/Product.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/ProductDetailsLink.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/ProductItem.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/ProductLink.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/ProductListEvent.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/ProductListItem.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/ProductListItemReference.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/ProductListLink.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/ProductListRegistrant.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/ProductListShippingAddress.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/ProductPromotion.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/ProductRecommendationsResult.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/ProductRef.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/ProductResult.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/ProductSearchHit.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/ProductSearchRefinement.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/ProductSearchRefinementValue.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/ProductSearchResult.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/ProductSearchSortingOption.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/ProductSimpleLink.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/ProductType.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/Promotion.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/PromotionLink.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/PromotionResult.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/PublicProductList.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/PublicProductListItem.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/PublicProductListItemResult.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/PublicProductListLink.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/PublicProductListResult.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/Recommendation.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/RecommendationType.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/Shipment.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/ShippingItem.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/ShippingMethod.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/ShippingMethodResult.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/ShippingPromotion.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/SimpleLink.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/Site.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/SortField.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/Status.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/Store.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/StoreResult.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/SuggestedCategory.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/SuggestedContent.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/SuggestedPhrase.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/SuggestedProduct.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/SuggestedTerm.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/SuggestedTerms.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/Suggestion.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/SuggestionResult.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/Variant.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/VariationAttribute.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/VariationAttributeValue.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/VariationGroup.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/shop/Documents/
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/AbTest.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/AbTestGroup.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/AbTestSearchResult.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/AbTestSegment.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/AbTestSegmentStats.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/AbTestTrigger.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/AbTests.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/AccountTransaction.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/ApplicationPermissions.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/BMPermissions.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/BoolFilter.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/BoolQuery.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/CSCPermissions.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/Campaign.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/CampaignPromotionExperience.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/CampaignSearchResult.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/CampaignSlotConfigurationExperience.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/CampaignSortingRuleExperience.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/Campaigns.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/CartridgePathAddRequest.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/CartridgePathApiResponse.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/CartridgePathCreateRequest.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/Catalog.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/CatalogCategoryId.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/CatalogSearchResult.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/Catalogs.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/Categories.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/Category.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/CategoryLink.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/CategoryLinks.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/CategoryProductAssignment.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/CategoryProductAssignmentSearchRequest.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/CategoryProductAssignmentSearchResult.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/CategorySearchResult.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/CodeVersion.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/CodeVersionResult.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/ContentAsset.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/ContentAssetResult.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/ContentFolder.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/ContentFolderAssignment.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/ContentFolderResult.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/ContentSubFolderResult.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/Coupon.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/CouponCode.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/CouponCodes.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/CouponMultiCodesRequest.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/CouponRedemption.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/CouponRedemptionSearchResult.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/CouponSearchResult.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/CouponSystemCodeConfig.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/Coupons.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/Credentials.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/CustomLogSettings.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/CustomObject.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/CustomObjectSearchResult.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/Customer.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/CustomerAddress.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/CustomerAddressResult.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/CustomerGroup.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/CustomerGroupMember.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/CustomerGroupMemberResult.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/CustomerGroupMemberSearchResult.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/CustomerGroupMembers.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/CustomerGroupResult.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/CustomerGroupSearchResult.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/CustomerGroups.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/CustomerList.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/CustomerListLink.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/CustomerSearchHit.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/CustomerSearchRequest.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/CustomerSearchResult.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/EcdnLogFetchRequest.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/EcdnLogFetchResponse.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/ExportDataUnitsConfiguration.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/ExportGlobalDataConfiguration.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/ExportSitesConfiguration.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/Fault.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/Filter.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/FilteredQuery.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/Flash.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/FunctionalPermission.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/FunctionalPermissions.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/GiftCertificate.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/GiftCertificateSearchResult.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/GiftCertificates.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/ImageGroup.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/InventoryList.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/InventoryListSearchResult.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/InventoryLists.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/JobExecution.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/JobExecutionParameter.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/JobExecutionRequest.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/JobExecutionResult.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/JobExecutionSearchResult.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/JobStepExecution.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/Locale.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/LocalePermission.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/LocalePermissions.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/LocaleResult.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/LogCategory.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/MarkupText.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/Master.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/MatchAllQuery.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/MediaFile.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/MenuAction.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/MenuItem.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/ModulePermissions.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/Money.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/NestedQuery.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/ObjectAttributeDefinition.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/ObjectAttributeDefinitionSearchResult.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/ObjectAttributeDefinitions.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/ObjectAttributeGroup.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/ObjectAttributeGroupSearchResult.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/ObjectAttributeGroups.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/ObjectAttributeValueDefinition.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/ObjectTypeDefinition.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/ObjectTypeDefinitionSearchResult.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/ObjectTypeDefinitions.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/OrganizationPreferences.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/PasswordChangeRequest.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/PathRecord.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/PreferenceValue.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/PreferenceValueSearchResult.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/Product.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/ProductInventoryRecord.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/ProductInventoryRecordAllocation.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/ProductInventoryRecords.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/ProductOption.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/ProductOptionValue.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/ProductOptionValues.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/ProductOptions.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/ProductSearchResult.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/ProductType.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/Promotion.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/PromotionABTestGroupAssignment.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/PromotionAssignmentInformation.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/PromotionCampaignAssignment.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/PromotionCampaignAssignmentSearchResult.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/PromotionSearchResult.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/Promotions.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/Query.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/QueryFilter.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/Range2Filter.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/RangeFilter.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/Recommender.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/RecommendersResult.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/Recurrence.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/RedemptionLimitPerPeriod.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/RedemptionLimits.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/ResultPage.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/Role.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/RoleFunctionalPermission.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/RoleFunctionalPermissions.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/RoleLocalePermission.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/RoleLocalePermissions.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/RoleModulePermission.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/RoleModulePermissions.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/RolePermissions.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/RoleSearchRequest.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/RoleSearchResult.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/RoleWebdavPermission.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/RoleWebdavPermissions.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/Roles.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/Rule.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/Schedule.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/SearchRequest.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/SearchResult.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/Site.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/SiteArchiveExportConfiguration.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/SiteArchiveImportConfiguration.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/SitePreferences.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/SiteSearchResult.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/Sites.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/Slot.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/SlotConfiguration.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/SlotConfigurationABTestGroupAssignment.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/SlotConfigurationAssignmentInformation.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/SlotConfigurationCampaignAssignment.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/SlotConfigurationCampaignAssignmentSearchResult.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/SlotConfigurationSearchResult.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/SlotConfigurations.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/SlotContent.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/SlotSearchResult.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/Slots.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/Sort.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/SortingRule.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/SortingRuleSearchResult.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/SortingRuleStep.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/SourceCodeGroup.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/SourceCodeGroupSearchResult.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/SourceCodeGroups.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/SourceCodeRedirectInfo.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/SourceCodeSpecification.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/Status.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/Store.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/StoreSearchResult.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/Stores.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/Tag.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/TermFilter.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/TermQuery.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/TextQuery.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/TimeOfDay.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/User.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/UserSearchResult.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/Users.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/Variant.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/VariantSearchResult.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/Variants.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/VariationAttribute.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/VariationAttributeValue.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/VariationAttributeValues.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/VariationAttributes.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/VariationGroup.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/VariationGroups.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/WebdavPermission.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/WebdavPermissions.html
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/
# https://documentation.demandware.com/DOC3/topic/com.demandware.dochelp/OCAPI/19.3/data/Documents/

# %%
if os.path.exists("./DWREApiDoc.docset/Contents/Resources/Documents/ocapi"):
    shutil.rmtree("./DWREApiDoc.docset/Contents/Resources/Documents/ocapi")
    
if not os.path.exists('./DWREApiDoc.docset/Contents/Resources/Documents/ocapi/'):
    os.makedirs('./DWREApiDoc.docset/Contents/Resources/Documents/ocapi/shop/Documents')
    os.makedirs('./DWREApiDoc.docset/Contents/Resources/Documents/ocapi/data/Documents')
    os.makedirs('./DWREApiDoc.docset/Contents/Resources/Documents/ocapi/shop/Resources')
    os.makedirs('./DWREApiDoc.docset/Contents/Resources/Documents/ocapi/data/Resources')

# %%
for link in LINKS:
    r = requests.get(link)
    r.raise_for_status()
    content = r.content.decode('utf-8').replace('self == top', 'self == "blah"')
    content = content.replace("</head>", css)
    name, ext = os.path.splitext(os.path.basename(link))
    print(name)
    if "shop/Resources" in link:
        entry_type = "Resource"
        entry_name = "SHOPAPI " + name
        entry_folder = "shop/Resources/"
    elif "shop/Documents" in link:
        entry_type = "Type"
        entry_name = "SHOPDOC "  + name
        entry_folder = "shop/Documents/"
    elif "data/Resources" in link:
        entry_type = "Resource"
        entry_name = "DATAAPI " + name
        entry_folder = "data/Resources/"
    elif "data/Documents" in link:
        entry_type = "Type"
        entry_name = "DATADOC "  + name
        entry_folder = "data/Documents/"
    else:
        entry_type = "Guide"
        entry_name = name
        entry_folder = ""
        
    c.execute("INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('%s', '%s', '%s');" % 
              (entry_name, entry_type, "ocapi/%s%s" % (entry_folder, name+".html")))
    with open(os.path.join('./DWREApiDoc.docset/Contents/Resources/Documents/ocapi/%s' % entry_folder, name+".html"), 'w') as f:
        f.write(content)
conn.commit()
# Out:
# RedemptionLimits
# RedemptionLimitPerPeriod
# ProductListShippingAddress
# Promotions
# CustomerProductListItemPurchaseResult
# SourceCodeRedirectInfo
# SourceCodeSpecification
# SortingRule
# Customer
# ImageGroup
# ProductInventoryRecords
# CustomerAddress
# GiftCertificate
# CampaignPromotionExperience
# BundledProduct
# OrderPaymentCardRequest
# ContentSearchResult
# OAuth
# ModulePermissions
# Sessions
# Variants
# PromotionCampaignAssignmentSearch
# Customization
# JSONP
# CatalogCategoryId
# Discount
# CouponCode
# BonusDiscountLineItem
# PublicProductListLink
# Campaign
# ContentFolderResult
# ApproachingDiscountResult
# ProductListRegistrant
# Customer
# VariationGroup
# AbTestTrigger
# UserSearchResult
# Roles
# Expansions
# ProductListLink
# Catalogs
# ProductInventoryRecord
# Rule
# InventoryListSearch
# SystemObjectDefinitionSearch
# CustomerProductListItemLink
# ObjectTypeDefinitionSearchResult
# CustomerSearchRequest
# CustomerPaymentInstrument
# PaymentCardRequest
# JWT
# SuggestionResult
# Product
# CustomerOrderResult
# VariationAttributes
# CustomerGroups
# BasketCreateRequest
# BasketsResult
# CategoryProductAssignmentSearch
# UserSearch
# CustomerProductListResult
# CustomerGroupMembers
# CategoryLinks
# ProductSearchResult
# ObjectAttributeValueDefinition
# PriceAdjustmentRequest
# LocalePermissions
# StoreSearch
# CodeVersion
# PromotionCampaignAssignment
# RoleSearch
# SimpleLink
# OptimisticLocking
# ProductDetailsLink
# Variant
# SuggestedProduct
# ShippingMethodResult
# AbTestSearchResult
# WebdavPermissions
# JobExecutionRequest
# Orders
# Coupons
# PromotionAssignmentInformation
# ObjectAttributeDefinitions
# ResourceStates
# SortingRuleStep
# Status
# AiProduct
# SourceCodeGroupSearch
# CustomerGroupResult
# Customers
# CodeVersions
# CustomerAddress
# Store
# SitePreferences
# RoleModulePermission
# Stores
# ProductRef
# OrderSearchHit
# PublicProductList
# VariationGroups
# SiteArchiveImportConfiguration
# CustomerAddressResult
# ContentSearchRefinement
# CodeVersionResult
# RoleLocalePermission
# ProductSearchSortingOption
# CustomObjectsSearch
# Tag
# FunctionalPermissions
# CORS
# LocaleResult
# SitePreferences
# Product
# SourceCodeGroupSearchResult
# TimeOfDay
# OptionValue
# PasswordChangeRequest
# TextQuery
# Promotion
# Content
# Locale
# ProductPromotion
# SuggestedCategory
# HttpHeaders
# AbTests
# Baskets
# Ai
# SystemJobs
# SlotConfigurationCampaignAssignmentSearchResult
# CartridgePathApiResponse
# PromotionSearch
# ContentFolderAssignment
# Jobs
# JobExecutionSearch
# Roles
# SiteSearch
# RecommendationType
# Suggestion
# Promotions
# MarkupText
# NestedQuery
# SortField
# ProductInventoryRecords
# UrlSchema
# ProductInventoryRecordAllocation
# SiteSearchResult
# CategoryResult
# HttpStatusCodesAndFaults
# Option
# Site
# LogRequests
# ActivityResult
# Shipment
# Master
# ProductOptionValues
# ProductOption
# CategorySearch
# PaymentMethod
# CartridgePathAddRequest
# CustomObjectSearchResult
# Range2Filter
# ExportGlobalDataConfiguration
# RoleSearchRequest
# NotesResult
# CustomerSearchResult
# CustomerGroupMemberResult
# PreferenceValue
# Basket
# MediaFile
# PriceAdjustmentLimits
# APIExplorer
# BoolFilter
# CustomObject
# Filter
# CustomerProductListItem
# RecommendersResult
# CouponRedemptionSearchResult
# Catalog
# ProductSearchRefinement
# ContentAssetResult
# OrderSearch
# CouponMultiCodesRequest
# PaymentCardSpec
# ContentResult
# ProductListItemReference
# Order
# ObjectAttributeGroupSearchResult
# CategoryProductAssignment
# VariantSearchResult
# CustomerAddressLink
# WebdavPermission
# JobStepExecution
# ShippingItem
# ProductSearch
# Flash
# ProductItem
# ObjectAttributeDefinitionSearchResult
# ObjectAttributeDefinition
# PromotionLink
# ProductListEvent
# ResultPage
# User
# Products
# GiftCertificateRequest
# Variant
# CustomerGroupMember
# ApplicationPermissions
# PromotionResult
# PromotionSearchResult
# Site
# CustomerAddressResult
# SlotContent
# LocaleInfo
# Users
# SourceCodeGroups
# ContentSubFolderResult
# SearchRequest
# Coupon
# Credentials
# SlotConfigurationSearchResult
# OrderAddress
# Fault
# Status
# RangeFilter
# PaymentCard
# MenuAction
# RoleWebdavPermissions
# Users
# RoleModulePermissions
# CouponRedemption
# BMPermissions
# SlotConfigurationABTestGroupAssignment
# CampaignSlotConfigurationExperience
# StoreResult
# Query
# CampaignSearch
# TermFilter
# Hooks
# PasswordReset
# Stores
# Sites
# VariationAttributeValues
# Locale
# JobExecution
# Recurrence
# Flash
# SiteArchiveExportConfiguration
# CategoryProductAssignmentSearchRequest
# Promotion
# GiftCertificates
# ProductType
# PathRecord
# Categories
# CatalogSearchResult
# CustomerGroupSearchResult
# BundledProductItem
# CustomerProductListItemPurchase
# CustomLogSettings
# ObjectAttributeGroups
# CustomerGroupSearch
# CustomerProductListRegistrant
# Metadata
# CampaignSortingRuleExperience
# Pagination
# DiscountRequest
# EcdnLogFetchRequest
# FunctionalPermission
# GiftCertificateSearchResult
# OCAPISettings
# CategoryProductAssignmentSearchResult
# ObjectTypeDefinitions
# InventoryListSearchResult
# MatchAllQuery
# PublicProductListResult
# CustomObjects
# OpenCommerceAPI
# PriceAdjustmentLimit
# VariationAttribute
# SortingRuleSearch
# AbTests
# RoleFunctionalPermission
# ExportDataUnitsConfiguration
# RoleWebdavPermission
# CustomerGroups
# CouponSystemCodeConfig
# CustomerRegistration
# Site
# ProductSearchResult
# SuggestedTerms
# CSCPermissions
# AccountTransaction
# GiftCertificates
# HttpMethods
# DataFormats
# BasketPaymentInstrumentRequest
# ProductLink
# SlotConfigurationSearch
# CouponSearch
# JobExecutionResult
# ContentSearch
# OrderSearchResult
# SlotSearch
# ContentSearchRefinementValue
# CustomProperties
# ProductOptions
# Note
# ClientApplicationIdentification
# ShippingMethod
# PromotionABTestGroupAssignment
# Permissions
# BoolQuery
# VariationAttributeValue
# EcdnLogFetchResponse
# PaymentBankAccountRequest
# CustomerList
# Recommendation
# Coupons
# Flash
# PaymentMethodResult
# ContentFolder
# CustomerProductListItemResult
# JobExecutionParameter
# SlotConfigurationCampaignAssignment
# CouponCodes
# AuthRequest
# Master
# Money
# Sites
# Slots
# RoleSearchResult
# SearchSuggestion
# CouponRedemptionSearch
# CustomerPaymentInstrumentRequest
# RoleFunctionalPermissions
# Libraries
# PriceAdjustmentLimits
# Categories
# OrderPaymentInstrument
# PromotionCampaignAssignmentSearchResult
# QueryFilter
# Category
# Recommender
# SlotConfigurations
# Promotions
# PreferenceValueSearchResult
# SortingRuleSearchResult
# Settings
# CategoryLinks
# ProductLists
# OrderPaymentInstrumentRequest
# GlobalPreferences
# PriceAdjustment
# Stores
# Filtering
# ActivityRequest
# ObjectTypeDefinition
# GiftCertificate
# ObjectAttributeGroup
# SlotConfigurations
# Store
# Categories
# SlotSearchResult
# OrderSearchRequest
# Slot
# AbTestSegment
# ContentFolder
# Localization
# Category
# CustomerSearchHit
# CustomObjects
# CategorySearchResult
# Campaigns
# Exceptions
# ProductSearchRefinementValue
# ShippingPromotion
# Content
# GiftCertificate
# Campaigns
# CategoryLink
# Inventory
# InventoryList
# SuggestedTerm
# ContentAsset
# CouponSearchResult
# SlotConfiguration
# CartridgePathCreateRequest
# SuggestedContent
# ApproachingDiscount
# ExportSitesConfiguration
# Sort
# CampaignSearchResult
# VariantSearch
# InventoryLists
# Slots
# ItemKey
# SourceCodeGroups
# CustomerPaymentInstrumentResult
# VariationAttributeValue
# CustomerInfo
# CouponItem
# ProductOptionValue
# BatchRequests
# StoreSearchResult
# AbTestGroup
# FilteredQuery
# TermQuery
# ProductSearchHit
# Schedule
# Role
# GiftCertificateItem
# Catalogs
# BasketReference
# ProductResult
# PropertySelection
# SuggestedPhrase
# MenuItem
# VariationAttribute
# Images
# CustomObjectDefinitions
# CustomObject
# OptionItem
# CatalogSearch
# CustomerProductList
# CustomerLists
# BestPractices
# Folders
# ImageGroup
# JobExecutionSearchResult
# Image
# AbTest
# SlotConfigurationAssignmentInformation
# PaymentBankAccount
# LocalePermission
# CustomerGroup
# LogCategory
# CustomerPaymentCardRequest
# ProductType
# CustomerGroupMemberSearchResult
# OrganizationPreferences
# RoleLocalePermissions
# ProductSimpleLink
# ContentFolderResult
# Fault
# PublicProductListItem
# AbTestSegmentStats
# SessionBridge
# PasswordChangeRequest
# PublicProductListItemResult
# SystemObjectDefinitions
# ProductListItem
# SearchResult
# Products
# SlotConfigurationCampaignAssignmentSearch
# InventoryLists
# CustomerListLink
# ProductRecommendationsResult
# ProductSearch
# GiftCertificateSearch
# VariationGroup
# RolePermissions
# AbTestSearch
# VersioningAndDeprecationPolicy
# SourceCodeGroup
# Caching

# %%
conn.close()
